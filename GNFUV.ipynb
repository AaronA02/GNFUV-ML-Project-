# %% [markdown]
# <a href="https://colab.research.google.com/github/AaronA02/GNFUV-ML-Project-/blob/main/GNFUV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=pd.read_excel('pi2.xlsx')
df2=pd.read_excel('pi3.xlsx')
df3=pd.read_excel('pi4.xlsx')
df4=pd.read_excel('pi5.xlsx')

# %%
df1.shape, df2.shape, df3.shape, df4.shape
# Out:
# ((580, 6), (807, 6), (1023, 6), (1407, 6))

# %%
df1.head(2)
# Out:
#                                 Device  Humidity  Temperature  Experiment  \
# 0   'gnfuv-temp-exp1-55d487b85b-t2rkn'        31           26           1
# 1   'gnfuv-temp-exp1-55d487b85b-t2rkn'        31           26           1
#
#                             time   Pi
# 0  2018-07-20 11:59:53.808660000  Pi2
# 1  2018-07-20 12:00:00.452504000  Pi2

# %%
df2.head()
# Out:
#                                 Device  Humidity  Temperature  Experiment  \
# 0   'gnfuv-temp-exp1-55d487b85b-b9wx5'        31           27           1
# 1   'gnfuv-temp-exp1-55d487b85b-b9wx5'        27           29           1
# 2   'gnfuv-temp-exp1-55d487b85b-b9wx5'        27           29           1
# 3   'gnfuv-temp-exp1-55d487b85b-b9wx5'        27           29           1
# 4   'gnfuv-temp-exp1-55d487b85b-b9wx5'        27           29           1
#
#                             time   Pi
# 0  2018-07-20 11:59:48.472181000  Pi3
# 1  2018-07-20 11:59:55.114928000  Pi3
# 2  2018-07-20 12:00:04.283027000  Pi3
# 3  2018-07-20 12:00:10.954970000  Pi3
# 4  2018-07-20 12:00:20.120889000  Pi3

# %%
df3.head()
# Out:
#                                 Device Humidity Temperature  Experiment  \
# 0   'gnfuv-temp-exp1-55d487b85b-2648d'       20          30           1
# 1   'gnfuv-temp-exp1-55d487b85b-2648d'       20          30           1
# 2   'gnfuv-temp-exp1-55d487b85b-2648d'       20          30           1
# 3   'gnfuv-temp-exp1-55d487b85b-2648d'       20          30           1
# 4   'gnfuv-temp-exp1-55d487b85b-2648d'       20          30           1
#
#                             time   Pi
# 0  2018-07-20 11:59:46.703104000  pi4
# 1  2018-07-20 11:59:53.391764000  pi4
# 2  2018-07-20 12:00:02.560356000  pi4
# 3  2018-07-20 12:00:11.759209000  pi4
# 4  2018-07-20 12:00:18.431610000  pi4

# %%
df4.head()
# Out:
#                                 Device  Humidity  Temperature  Experiment  \
# 0   'gnfuv-temp-exp1-55d487b85b-5dmwq'        26           30           1
# 1   'gnfuv-temp-exp1-55d487b85b-5dmwq'        25           30           1
# 2   'gnfuv-temp-exp1-55d487b85b-5dmwq'        25           30           1
# 3   'gnfuv-temp-exp1-55d487b85b-5dmwq'        25           30           1
# 4   'gnfuv-temp-exp1-55d487b85b-5dmwq'        25           30           1
#
#                             time   Pi
# 0  2018-07-20 11:59:44.533826000  pi5
# 1  2018-07-20 11:59:51.217489000  pi5
# 2  2018-07-20 11:59:57.856444000  pi5
# 3  2018-07-20 12:00:04.496282000  pi5
# 4  2018-07-20 12:00:11.136256000  pi5

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407 entries, 0 to 1406
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Device       1407 non-null   object
#  1   Humidity     1407 non-null   int64
#  2   Temperature  1407 non-null   int64
#  3   Experiment   1407 non-null   int64
#  4   time         1407 non-null   object
#  5   Pi           1407 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 66.1+ KB

# %% [markdown]
# ### Joining Data

# %%
df= pd.concat([df1, df2, df3,df4])

# %%
df
# Out:
#                                    Device Humidity Temperature  Experiment  \
# 0      'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
# 1      'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
# 2      'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
# 3      'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
# 4      'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
# ...                                   ...      ...         ...         ...
# 1402   'gnfuv-temp-exp1-55d487b85b-t4l7k'       22          48           1
# 1403   'gnfuv-temp-exp1-55d487b85b-8n4q6'       22          48           1
# 1404   'gnfuv-temp-exp1-55d487b85b-t4l7k'       21          47           1
# 1405   'gnfuv-temp-exp1-55d487b85b-8n4q6'       22          48           1
# 1406   'gnfuv-temp-exp1-55d487b85b-t4l7k'       21          48           1
#
#                                time   Pi
# ...

# %%
#Jumbling the whole dataset
df= df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                                    Device Humidity Temperature  Experiment  \
# 0      'gnfuv-temp-exp1-55d487b85b-8n4q6'       28          40           1
# 1      'gnfuv-temp-exp1-55d487b85b-bpwnk'       26          41           1
# 2      'gnfuv-temp-exp1-55d487b85b-t4l7k'       29          40           1
# 3      'gnfuv-temp-exp1-55d487b85b-8n4q6'       34          37           1
# 4      'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
# ...                                   ...      ...         ...         ...
# 3812   'gnfuv-temp-exp1-55d487b85b-8ssmh'       26          51           1
# 3813   'gnfuv-temp-exp1-55d487b85b-4sc5v'       22          55           1
# 3814   'gnfuv-temp-exp1-55d487b85b-8n4q6'       29          40           1
# 3815   'gnfuv-temp-exp1-55d487b85b-bpwnk'       23          42           1
# 3816   'gnfuv-temp-exp1-55d487b85b-t4l7k'       26          40           1
#
#                                time   Pi
# ...

# %% [markdown]
# ### Profile Report

# %%
from pandas_profiling import ProfileReport

# %%
ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-04-10 17:39:43.333123&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## <div class='alert alert-success'> Data Preprocessing </div>

# %%
df.head()
# Out:
#                                 Device Humidity Temperature  Experiment  \
# 0   'gnfuv-temp-exp1-55d487b85b-8n4q6'       28          40           1
# 1   'gnfuv-temp-exp1-55d487b85b-bpwnk'       26          41           1
# 2   'gnfuv-temp-exp1-55d487b85b-t4l7k'       29          40           1
# 3   'gnfuv-temp-exp1-55d487b85b-8n4q6'       34          37           1
# 4   'gnfuv-temp-exp1-55d487b85b-t2rkn'       31          26           1
#
#                             time   Pi
# 0  2018-07-20 13:12:46.781537000  pi5
# 1  2018-07-20 12:45:19.962594000  Pi3
# 2  2018-07-20 13:04:31.260195000  pi5
# 3  2018-07-20 12:34:31.709108000  pi5
# 4  2018-07-20 12:00:25.411927000  Pi2

# %% [markdown]
# ### <font color='green'>Handling null values</font>

# %%
df.isnull().sum()
# Out:
# Device         0
# Humidity       0
# Temperature    0
# Experiment     0
# time           0
# Pi             0
# dtype: int64

# %% [markdown]
# No null values so nothing to handle

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### <font color='green'>Removing Experiment column as it contains only 1 type of value</font>

# %%
df['Experiment'].unique()
# Out:
# array([1])

# %%
df=df.drop('Experiment',axis=1)

# %% [markdown]
# ### <font color='green'>Label Encoding</font>

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df.columns
# Out:
# Index(['Device', 'Humidity', 'Temperature', 'time', 'Pi'], dtype='object')

# %%
for i in['Device','time']:
    df[i]=lb.fit_transform(df[i])

# %%
df["Pi"] = df["Pi"].replace({"pi4": 3, "Pi3": 2, "Pi2": 1, "pi5": 4})

# %%
df.head()
# Out:
#    Device Humidity Temperature  time  Pi
# 0       5       28          40  1862   4
# 1       8       26          41   810   2
# 2      16       29          40  1551   4
# 3       5       34          37   473   4
# 4      15       31          26    21   1

# %% [markdown]
# ### <font color='green'>Converting Humidity and Temperature to Int</font>

# %%
df.head()
# Out:
#    Device Humidity Temperature  time  Pi
# 0       5       28          40  1862   4
# 1       8       26          41   810   2
# 2      16       29          40  1551   4
# 3       5       34          37   473   4
# 4      15       31          26    21   1

# %%
df[df['Humidity']==' None']
# Out:
#       Device Humidity Temperature  time  Pi
# 2159      11     None        None  3123   3
# 3431       2     None        None  3124   3

# %%
df[df['Temperature']==' None']
# Out:
#       Device Humidity Temperature  time  Pi
# 2159      11     None        None  3123   3
# 3431       2     None        None  3124   3

# %%
df=df.drop([2159,3431])

# %%
df['Temperature']=df['Temperature'].astype('int')
df['Humidity']=df['Humidity'].astype('int')

# %% [markdown]
# ### <font color='green'>Let us check the correlation</font>

# %%
sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# ### <font color='green'>Using Standard Scaler </font>

# %%
df.columns
# Out:
# Index(['Device', 'Humidity', 'Temperature', 'time', 'Pi'], dtype='object')

# %%
x=df.drop('Pi',axis=1)

# %%
y=df['Pi']

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
xx=scaler.fit_transform(x)

# %%
xx
# Out:
# array([[0.29411765, 0.36363636, 0.42424242, 0.50916051],
#        [0.47058824, 0.3030303 , 0.45454545, 0.22149303],
#        [0.94117647, 0.39393939, 0.42424242, 0.42411813],
#        ...,
#        [0.29411765, 0.39393939, 0.42424242, 0.67432322],
#        [0.47058824, 0.21212121, 0.48484848, 0.3604047 ],
#        [0.94117647, 0.3030303 , 0.42424242, 0.55756084]])

# %%
pd.DataFrame(xx)
# Out:
#              0         1         2         3
# 0     0.294118  0.363636  0.424242  0.509161
# 1     0.470588  0.303030  0.454545  0.221493
# 2     0.941176  0.393939  0.424242  0.424118
# 3     0.294118  0.545455  0.333333  0.129341
# 4     0.882353  0.454545  0.000000  0.005742
# ...        ...       ...       ...       ...
# 3808  0.352941  0.303030  0.757576  0.593656
# 3809  0.117647  0.181818  0.878788  0.671042
# 3810  0.294118  0.393939  0.424242  0.674323
# 3811  0.470588  0.212121  0.484848  0.360405
# 3812  0.941176  0.303030  0.424242  0.557561
#
# [3813 rows x 4 columns]

# %%
df=pd.DataFrame(xx,columns=x.columns)
df.head()
# Out:
#      Device  Humidity  Temperature      time
# 0  0.294118  0.363636     0.424242  0.509161
# 1  0.470588  0.303030     0.454545  0.221493
# 2  0.941176  0.393939     0.424242  0.424118
# 3  0.294118  0.545455     0.333333  0.129341
# 4  0.882353  0.454545     0.000000  0.005742

# %% [markdown]
# ### <font color='green'>Train test Split </font>

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3,random_state=10)

# %%
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((2669, 4), (1144, 4), (2669,), (1144,))

# %% [markdown]
# ## <div class='alert alert-success'> Model Prediction </div>

# %%
from sklearn.linear_model import Perceptron
p1 = Perceptron(penalty = 'l1')

# %%
p1.fit(xtrain, ytrain)
# Out:
# Perceptron(penalty='l1')

# %%
from sklearn.metrics import accuracy_score

# %%
train_pred = p1.predict(xtrain)

# %%
test_pred = p1.predict(xtest)

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.linear_model  import LogisticRegression

# %%
lr=LogisticRegression(random_state=42)

# %%
lr.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
y_pred = lr.predict(xtest)

# %%
lr.score(xtest,ytest)
# Out:
# 0.7281468531468531

# %%
train_pred = p1.predict(xtrain)

# %%
print("Training Accuracy : ", accuracy_score(train_pred, ytrain))
# Out:
# Training Accuracy :  0.4353690520794305

# %%
print("Testing Accuracy  : ", accuracy_score(test_pred, ytest))
# Out:
# Testing Accuracy  :  0.4090909090909091

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC

# %%
svc=SVC(random_state=77)

# %%
svc.fit(xtrain,ytrain)
# Out:
# SVC(random_state=77)

# %%
svc_train_pred = svc.predict(xtrain)
svc_test_pred = svc.predict(xtest)

# %%
print("Training accuracy SVM: ", accuracy_score(ytrain, svc_train_pred))
# Out:
# Training accuracy SVM:  0.3892843761708505

# %%
print("Testing accuracy SVM: ", accuracy_score(ytest, svc_test_pred))
# Out:
# Testing accuracy SVM:  0.36713286713286714

# %%
y_pred = lr.predict(xtest)

# %%
svc.score(xtest,ytest)
# Out:
# 0.36713286713286714

# %% [markdown]
# ### DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc=DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)

# %%
dc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
dt1_train_pred = dc.predict(xtrain)

# %%
dt1_test_pred = dc.predict(xtest)

# %%
print("Training accuracy entropy : ", accuracy_score(ytrain, dt1_train_pred))
# Out:
# Training accuracy entropy :  0.9580367178718622

# %%
print("Testing accuracy entropy : ", accuracy_score(ytest, dt1_test_pred))
# Out:
# Testing accuracy entropy :  0.9667832167832168

# %%
y_pred = dc.predict(xtest)

# %%
dc.score(xtest,ytest)
# Out:
# 0.9667832167832168

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(dc);

# %% [markdown]
# ## <div class='alert alert-success'>Hyperparameter Tuning </div>

# %% [markdown]
#  - Let's use hyperparameter tuning now and see the difference

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

param_range = [0.001, 0.01, 0.1, 1]
param = [{"kernel" : ['linear'], 'C' : param_range},
         {"kernel" : ['poly'], 'C' : param_range},
         {"kernel" : ['rbf'], 'C' : param_range, 'gamma' : param_range}]

gs = GridSearchCV(SVC(), param_grid = param, scoring = 'accuracy', cv = 2)

x = df.drop('Device', axis=1)
y = df['Device'].astype(int)
# y.info()

# # # Load training data and labels into X_train and y_train variables
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

score = []
# # # Fit the grid search object to the training data
gs.fit(x, y)
dc.fit(x, y)
score.append(dc.score(x, y))

# %%
print(np.average(score))
# Out:
# 0.948334644636769

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

def allRegressors(x_train, x_test, y_train, y_test):
   
    Regressors = [LinearRegression(), SVC(),DecisionTreeClassifier()]
    mae_dict = {}
    mae_scores = []
    rmse_dict = {}
    rmse_scores = []
    
    # function for mean absolute error
    def maeScore(regressor):
        
        clf = regressor.fit(x_train, y_train)
        pred = clf.predict(x_test)
        mae_score = mean_absolute_error(y_test, pred)
        return mae_score
    
    # function for root mean square error
    def rmseScore(regressor):
        
        clf = regressor.fit(x_train, y_train)
        pred = clf.predict(x_test)
        rmse_score = np.sqrt(mean_squared_error(y_test, pred))
        return rmse_score
    
    # mean absolute error, root mean square error for each regressors
    for regressor in Regressors:
        name = regressor.__class__.__name__
        mae_dict[name] = maeScore(regressor)
        mae_scores.append(maeScore(regressor))
        rmse_dict[name] = rmseScore(regressor)
        rmse_scores.append(rmseScore(regressor))
        print("*************************************************************************")
        print(f"{name} Mean Absolute Error = {mae_dict[name]}")
        print(f"{name} Root Mean Square Error = {rmse_dict[name]}")
        
    #Plotting the performance of regressors
    def plotPerformance(scores_list, scores_dict, metric:str):
        
        N = len(Regressors)
        w = 0.5
        x = np.arange(N)
        plt.bar(x, scores_list, width = w, align = 'center', color="g")
        plt.xlabel("Regressors")
        plt.title("Performance Comparison of Regressors")
        plt.ylabel(f"{metric} Error")
        plt.xticks(x, scores_dict.keys(), rotation=90)
        plt.yticks(np.arange(0, np.max(scores_list), np.max(scores_list)/len(scores_list)))
        plt.show()
    
    # call the functions
    plotPerformance(mae_scores, mae_dict, "Mean Absolute")
    plotPerformance(rmse_scores, rmse_dict, "Root Mean Square")

# %%
ytrain.astype(float)
# Out:
# 3217    1.0
# 1853    4.0
# 3708    1.0
# 548     3.0
# 2950    3.0
#        ...
# 3445    2.0
# 1344    3.0
# 527     2.0
# 3199    4.0
# 1289    3.0
# Name: Pi, Length: 2669, dtype: float64

# %%
allRegressors(xtrain,xtest,ytrain,ytest)
# Out:
# *************************************************************************
# LinearRegression Mean Absolute Error = 0.7815816818171434
# LinearRegression Root Mean Square Error = 0.906296113010005
# *************************************************************************
# SVC Mean Absolute Error = 1.0244755244755244
# SVC Root Mean Square Error = 1.4142135623730951
# *************************************************************************
# DecisionTreeClassifier Mean Absolute Error = 0.006118881118881119
# DecisionTreeClassifier Root Mean Square Error = 0.11450715310358611
